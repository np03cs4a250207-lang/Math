# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs4a250207-lang/Math/blob/main/Workshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *  **Name: Abinash yadav**
# *  *University ID:2610507*

# %%
length = 10 #variable1
width = 5 #variable2
area = length * width #This is called an expression
print(area)
# Out:
# 50

# %%
base = 6
height = 2
area = base*height/2
print("Area is " + str(area))
# Out:
# Area is 6.0

# %%
hrs = input("Enter Hours:")
h = float(hrs)
rate = input("Enter the rate per hour:")
r = float(rate)
if h <= 40:
  pay = h*r
else:
  pay = 40*r + (h-40)*r*2
print(pay)
# Out:
# Enter Hours:45
# Enter the rate per hour:15
# 750.0

# %%
def greeting (name):
  print("welcome "+ name)
greeting("Abinash yadav")
# Out:
# welcome Abinash yadav

# %%
def area_traingle(b, h):
    return b*h/2
area = area_traingle(4, 8)
print("area of traingle is: " + str(area))
# Out:
# area of traingle is: 16.0

# %%
def order_numbers(number1, number2):
  if number2 > number1:
    return number1,number2
  else:
      return number2,number1
print(order_numbers(4,3))
# Out:
# (3, 4)

# %%
def is_Even(number):
  if (number%2 == 0):
    return True
  return False
print(is_Even(7))
# Out:
# False

# %%
def number_group(number):
   if number > 0:
    return "Positive"
   elif number == 0:
     return "Zero"
   else:
     return "Negative"
print(number_group(10))
print(number_group(0))
print(number_group(-5))
# Out:
# Positive
# Zero
# Negative

# %%
x = 0 # initialzation of variable Why=?
while x<5:
   print("Not there yet, x= " + str(x))
   x = x+1
print("x= "+str(x))
# Out:
# Not there yet, x= 0
# Not there yet, x= 1
# Not there yet, x= 2
# Not there yet, x= 3
# Not there yet, x= 4
# x= 5

# %%
def count_down(start_number):
  current=3 #initialzation of variable
  while (current > 0):
    print(current)
    current -= 1
  print("Zero!")
count_down(3)
# Out:
# 3
# 2
# 1
# Zero!

# %%
while x%2 == 0:
  if x == 0:
   break
  x = x/2

print(x)
# Out:
# 5
